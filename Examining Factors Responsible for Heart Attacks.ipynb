# %% [raw]
#                     Examining Factors Responsible for Heart Attacks
#                             HEALTHCARE DOMAIN

# %%
#Important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print('ALL ARE IMPORTED')
# Out:
# ALL ARE IMPORTED

# %%
df = pd.read_excel('C:/Users/sharm/OneDrive/Desktop/project/1582800613_project3datadictionary/data.xlsx')

# %%
##top 5 rows
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
### no. of 
df.shape
# Out:
# (303, 14)

# %%
##data type
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
### print information of dat
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
##
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
##statiscial summary
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
##print no. of categories in data
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
## make some column as categorical
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['sex']=df['sex'].astype('object')
df['cp']=df['cp'].astype('object')
df['fbs']=df['fbs'].astype('object')
df['restecg']=df['restecg'].astype('object')
df['exang']=df['exang'].astype('object')
df['slope']=df['slope'].astype('object')
df['thal']=df['thal'].astype('object')
df['ca']=df['ca'].astype('object')

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# cp           object
# trestbps      int64
# chol          int64
# fbs          object
# restecg      object
# thalach       int64
# exang        object
# oldpeak     float64
# slope        object
# ca           object
# thal         object
# target        int64
# dtype: object

# %%
df['cp'].value_counts()   ## checking category
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
###  exploratory data analysis
#Performing EDA and Modeling:

#Describe the relationship between cholesterol levels and our target variable.

#What can be concluded about the relationship between peak exercising and occurrence of heart attack?

#Is thalassemia a major cause of CVD? How are the other factors determining the occurrence of CVD?

#Use a pair plot to understand the relationship between all the given variables.

#Perform logistic regression, predict the outcome for test data, and validate the results by using the confusion matrix.

#Dashboarding:###

# %%
## TARGET DATA
# target data
print(df['target'].value_counts())
df['target'].value_counts().plot(kind='bar')
plt.title('Heart Diseases')
plt.show()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
## replace in this target temporary
df['target'].replace({1:'Disease',0:'No_Disease'})
# Out:
# 0         Disease
# 1         Disease
# 2         Disease
# 3         Disease
# 4         Disease
#           ...
# 298    No_Disease
# 299    No_Disease
# 300    No_Disease
# 301    No_Disease
# 302    No_Disease
# Name: target, Length: 303, dtype: object

# %%
# show distribution of Age
sns.histplot(x=df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
df['age'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['age'].value_counts()
# Out:
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 60    11
# 44    11
# 56    11
# 64    10
# 41    10
# 63     9
# 67     9
# 65     8
# 43     8
# 45     8
# 55     8
# 42     8
# 61     8
# 53     8
# 46     7
# 48     7
# 66     7
# 50     7
# 49     5
# 47     5
# 70     4
# 39     4
# 35     4
# 68     4
# 38     3
# 71     3
# 40     3
# 69     3
# 34     2
# 37     2
# 29     1
# 74     1
# 76     1
# 77     1
# Name: age, dtype: int64

# %%
###age statics
# age stat
print(min(df['age']))
print(max(df['age']))
print('mean',df['age'].mean())
# Out:
# 29
# 77
# mean 54.366336633663366

# %%
## show distribuation pf gender
df['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
print(df['sex'].value_counts())
df['sex'].value_counts().plot(kind='bar')
plt.title('Gender Distribution')
plt.show()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
### chest pain analysis(cp)
print(df['cp'].value_counts())
df['cp'].value_counts().plot(kind='bar')
plt.title('Chest Pain Analysis')
plt.show()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
sns.countplot(x=df ['cp'])
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
##Resting ECG Analysis(restecg)
print(df['restecg'].value_counts())
df['restecg'].value_counts().plot(kind='bar')
plt.title('Resting ECG Analysis')
plt.show()
# Out:
# 1    152
# 0    147
# 2      4
# Name: restecg, dtype: int64

# %%
print(df['ca'].value_counts())
df['ca'].value_counts().plot(kind='bar')
plt.title('CA Analysis')
plt.show()
# Out:
# 0    175
# 1     65
# 2     38
# 3     20
# 4      5
# Name: ca, dtype: int64

# %%
print(df['thal'].value_counts())
sns.countplot(x=df['thal'])
plt.title('thal analysis')
plt.show()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %%
#Visualize categorical data distribution with target variable
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['target'].replace({1:'Disease',0:'No_Disease'},inplace =True)

# %%
##disease  class according to 
sns.countplot(x='sex',hue='target',data=df)
plt.title('Diseases classes according to Gender')
# Out:
# Text(0.5, 1.0, 'Diseases classes according to Gender')

# %%
##disease  class according to 
sns.countplot(x='cp',hue='target',data=df)
plt.title('Diseases classes according to cp')
# Out:
# Text(0.5, 1.0, 'Diseases classes according to cp')

# %%
##disease  class according to 
sns.countplot(x='thal',hue='target',data=df)
plt.title('Diseases classes according to thal')
# Out:
# Text(0.5, 1.0, 'Diseases classes according to thal')

# %%
##disease  class according to 
sns.countplot(x='exang',hue='target',data=df)
plt.title('Diseases classes according to Excercise Induced Angina')
# Out:
# Text(0.5, 1.0, 'Diseases classes according to Excercise Induced Angina')

# %%
##disease  class according to 
sns.countplot(x='fbs',hue='target',data=df)
plt.title('Diseases classes according to fbs')
# Out:
# Text(0.5, 1.0, 'Diseases classes according to fbs')

# %%
##disease  class according to 
sns.countplot(x='ca',hue='target',data=df)
plt.title('Diseases classes according to ca')
# Out:
# Text(0.5, 1.0, 'Diseases classes according to ca')

# %%
#### making subplot for combining the charts
#sns.pairplot(df, hue='target')
#plt.show()

# %%
### pie chart to show thal with heart disease and without it
# pie chart to show the Thal with heart diseases & without it
dis =[2,4,125,24]
nondis= [2,6,27,83]
labels=['zero','normal','fixed defect','reversible defect']
sizes=[2,4,125,24]
plt.pie(sizes,labels=labels,colors=['pink','orange','green','purple'],autopct='%.1f%%', startangle=140)
plt.title('thal With Heart Disease')
plt.show()

labels=['zero','normal','fixed defect','reversible defect']
sizes=[2,6,27,83]
plt.pie(sizes,labels=labels,colors=['pink','orange','green','purple'],autopct='%.1f%%', startangle=140)
plt.title('thal Without Heart Disease')
plt.show()

# %%
##use a pair plot to understand the relationship between all the given variables.
#(pair plot is done for numerical feature or variables)

# %%
df_num=df.select_dtypes(exclude='object')

df_num
# Out:
#      age  trestbps  chol  thalach  oldpeak
# 0     63       145   233      150      2.3
# 1     37       130   250      187      3.5
# 2     41       130   204      172      1.4
# 3     56       120   236      178      0.8
# 4     57       120   354      163      0.6
# ..   ...       ...   ...      ...      ...
# 298   57       140   241      123      0.2
# 299   45       110   264      132      1.2
# 300   68       144   193      141      3.4
# 301   57       130   131      115      1.2
# 302   57       130   236      174      0.0
#
# [303 rows x 5 columns]

# %%
df_num.columns
# Out:
# Index(['age', 'trestbps', 'chol', 'thalach', 'oldpeak'], dtype='object')

# %%
col= ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
sns.pairplot(df[col+['target']],hue='target')

# %%
#### to understand relationship between age and cholestrol  based on gender
sns.lmplot(x= 'age',y='chol', hue= 'sex', col = 'target', data =df, markers= ['o', 'x'])

# %%
'''# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot Resting Blood Pressure vs. CVD occurrence
axs[0, 0].scatter(df['Resting BP'], df['CVD'])
axs[0, 0].set_xlabel('Resting BP')
axs[0, 0].set_ylabel('CVD')

# Plot Age vs. CVD occurrence
axs[0, 1].scatter(df['Age'], df['CVD'])
axs[0, 1].set_xlabel('Age')
axs[0, 1].set_ylabel('CVD')

# Plot Cholesterol vs. CVD occurrence
axs[1, 0].scatter(df['Cholesterol'], df['CVD'])
axs[1, 0].set_xlabel('Cholesterol')
axs[1, 0].set_ylabel('CVD')

# Plot Max HR vs. CVD occurrence
axs[1, 1].scatter(df['Max HR'], df['CVD'])
axs[1, 1].set_xlabel('Max HR')
axs[1, 1].set_ylabel('CVD')

# Show the plot
plt.show()'''
# Out:
# "# Create a 2x2 grid of subplots\nfig, axs = plt.subplots(2, 2, figsize=(10, 8))\n\n# Plot Resting Blood Pressure vs. CVD occurrence\naxs[0, 0].scatter(df['Resting BP'], df['CVD'])\naxs[0, 0].set_xlabel('Resting BP')\naxs[0, 0].set_ylabel('CVD')\n\n# Plot Age vs. CVD occurrence\naxs[0, 1].scatter(df['Age'], df['CVD'])\naxs[0, 1].set_xlabel('Age')\naxs[0, 1].set_ylabel('CVD')\n\n# Plot Cholesterol vs. CVD occurrence\naxs[1, 0].scatter(df['Cholesterol'], df['CVD'])\naxs[1, 0].set_xlabel('Cholesterol')\naxs[1, 0].set_ylabel('CVD')\n\n# Plot Max HR vs. CVD occurrence\naxs[1, 1].scatter(df['Max HR'], df['CVD'])\naxs[1, 1].set_xlabel('Max HR')\naxs[1, 1].set_ylabel('CVD')\n\n# Show the plot\nplt.show()"
